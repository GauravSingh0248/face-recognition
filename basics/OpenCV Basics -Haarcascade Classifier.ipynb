# %%
import cv2
import matplotlib.pyplot as plt

# %%
# how to detect certain area in image

# %%
img=cv2.imread('kids.jpg')
print(img.shape)
# Out:
# (667, 1000, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 999.5, 666.5, -0.5)

# %% [markdown]
# **Haarcascade Classifier**

# %% [raw]
# **Few Things to Note About Haar Cascade Classifiers
#
# A Haar Cascade Classifier can detect objects in images regardless of scale (size) and location.
#
# You can train a Haar Cascade to detect different types of objects — such as faces, cars, bikes, buildings, fruits, etc.
#
# Advantages:
#
# Fast and efficient — works in real-time even on low-powered devices.
#
# Simple to implement in OpenCV using pre-trained XML models.
#
# Requires less computing power compared to deep learning models.
#
# Disadvantages:
#
# Not as accurate as modern object detection techniques like YOLO, SSD, or Faster R-CNN.
#
# Produces many false positives — regions incorrectly marked as the target object.**

# %%
model=cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

# %%
faces=model.detectMultiScale(img,1.3,1)

# %%
faces
# Out:
# array([[329,  19,  74,  74],
#        [463,  63,  97,  97],
#        [458, 222, 125, 125],
#        [241, 242, 131, 131],
#        [673, 302, 163, 163],
#        [357, 348, 147, 147],
#        [ 41, 412, 163, 163],
#        [646, 154, 125, 125],
#        [580, 278, 105, 105]])

# %%
for f in faces:
    # print(f)   # x ,y , height ,width , for the corner axis just add h and w (x+w,y+h)
    x,y,w,h=f
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(img)

# %%
# face detection in the video
